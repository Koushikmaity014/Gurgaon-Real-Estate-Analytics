# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('/content/gurgaon_properties_cleaned_v2.csv')

# %%
df.shape
# Out:
# (3803, 23)

# %%
df.head()
# Out:
#   property_type                           society      sector  price  \
# 0         house  bestech park view aindependentda   sector 81   4.35
# 1          flat           signature global solera  sector 107   0.28
# 2         house                emaar mgf marbella   sector 66    NaN
# 3          flat                 hcbs sports ville  sohna road   0.29
# 4          flat                     orchid petals   sector 49   2.55
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7937.0  5481.0                       Plot area 5480(509.11 sq.m.)
# 1          5674.0   493.0                     Carpet area: 489 (45.43 sq.m.)
# 2             NaN     NaN                        Plot area 350(292.64 sq.m.)
# 3          5587.0   519.0                     Carpet area: 519 (48.22 sq.m.)
# 4         12318.0  2070.0  Super Built up area 2070(192.31 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum facing   agePossession  \
# ...

# %% [markdown]
# price

# %%
sns.distplot(df['price'])
# Out:
# /tmp/ipykernel_1295/4207564571.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (432,
#  count    432.000000
#  mean       9.196157
#  std        4.061291
#  min        5.350000
#  25%        6.400000
#  50%        8.000000
#  75%       10.607500
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 2107         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 1690         house                                        independent
# 2095         house                                     dlf city plots
# 1784         house                                        independent
# 1760         house                                   suncity township
# 691          house                             emaar the palm springs
# 2410         house                                        independent
# 868          house                                 vipul tatvam villa
# 2266         house                                     dlf city plots
# 3519         house                             luxury dlf city floors
# 1957         house                                        independent
# 3699         house                                        independent
# ...

# %%
outliers.to_csv('price_outliers.csv',index=False)

# %% [markdown]
#  on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# price_per_squre_fit

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# /tmp/ipykernel_1295/2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (367,
#  count       367.000000
#  mean      52115.435967
#  std       60746.225927
#  min       24202.000000
#  25%       27778.000000
#  50%       33333.000000
#  75%       41790.000000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft.to_csv('price_per_sqft_outliers.csv')

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# /tmp/ipykernel_1295/205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# /tmp/ipykernel_1295/3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      367.000000
# mean     29160.735695
# std      12308.413881
# min       2689.000000
# 25%      25051.500000
# 50%      29630.000000
# 75%      35489.000000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# /tmp/ipykernel_1295/2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
outliers_2_0=df[df['price_per_sqft']>50000]

# %%
outliers_2_0
# Out:
#      property_type                       society      sector  price  \
# 301          house                   independent   sector 26  14.75
# 691          house        emaar the palm springs   sector 54  24.00
# 693          house                unitech escape   sector 50  10.80
# 726          house            cloudnine cottages  sohna road   5.50
# 820          house        emaar the palm springs   sector 54  14.00
# 944          house                   independent   sector 25  16.00
# 1784         house                   independent   sector 26  26.00
# 2095         house                dlf city plots   sector 26  26.00
# 2248         house                           nul   sector 28  12.50
# 2314         house                  malibu towne   sector 47   8.50
# 2563         house            emaar mgf marbella   sector 66  18.00
# 2761         house  project housing board colony   sector 31   8.00
# 2828          flat                unitech vistas   sector 70   9.00
#
# ...

# %%
outliers_2_0.to_csv('price_per_sqft_outliers_2_0.csv')

# %% [markdown]
# these points are genoin data points

# %% [markdown]
# # area

# %%
sns.distplot(df['area'])
# Out:
# /tmp/ipykernel_1295/91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3785.000000
# mean       2905.157199
# std       22783.155799
# min         145.000000
# 25%        1259.000000
# 50%        1745.000000
# 75%        2341.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 139           flat  signature global solera 2  sector 107   0.51
# 488          house                independent   sector 50   5.00
# 1908          flat            ramsons kshitij   sector 95   0.31
# 2776          flat          hcbs sports ville  sohna road   0.35
# 3767          flat      signature the roselia   sector 95   0.45
#
#       price_per_sqft      area                           areaWithType  \
# 139              9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 488            232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 1908             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 2776             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 3767             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 139         2         2       1       3.0       North    New Property
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# /tmp/ipykernel_1295/91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 2956         house                independent   sector 26  18.40
# 2763         house  ganpati heights apartment   sector 13   1.25
# 2716          flat                 rof ananda   sector 95   0.38
# 3010          flat                 rof ananda   sector 95   0.38
# 2046         house      dlf city plot phase 4   sector 28  13.00
# 279           flat              pyramid elite   sector 86   0.46
# 3018          flat                 rof ananda   sector 95   0.33
# 2623          flat      signature the serenas  sohna road   0.28
# 1788         house                independent   sector 25   7.30
# 2602          flat            ramsons kshitij   sector 95   0.24
# 176           flat                 rof ananda   sector 95   0.21
# 1833         house                independent   sector 57   6.25
# 970          house                independent   sector 43   5.50
# ...

# %%
df.drop(index=[2956, 2716,3010,279,3018,2623,2602,176,2307], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 2763         house  ganpati heights apartment   sector 13   1.25
# 2046         house      dlf city plot phase 4   sector 28  13.00
# 1788         house                independent   sector 25   7.30
# 1833         house                independent   sector 57   6.25
# 970          house                independent   sector 43   5.50
# 2571          flat                 godrej air   sector 85   2.50
# 1944         house       unitech aspen greens   sector 50   6.95
# 2679          flat                godrej icon  sector 88a   1.75
# 1690         house                independent   sector 43  27.50
# 923           flat             m3m golfestate   sector 65  13.20
# 539          house                independent  sohna road   5.50
#
#       price_per_sqft     area  \
# 2763           151.0  82781.0
# 2046          1992.0  65261.0
# 1788          1560.0  46795.0
# 1833          2778.0  22498.0
# ...

# %%
df.loc[2763,'area'] = 115*9
df.loc[2046,'area'] = 7250
df.loc[1788,'area'] = 5800
df.loc[1833,'area'] = 2660
df.loc[970,'area'] = 2850
df.loc[2571,'area'] = 1812
df.loc[1944,'area'] = 2160
df.loc[2679,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# /tmp/ipykernel_1295/91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3771.000000
# mean      1944.131265
# std       1213.337502
# min        145.000000
# 25%       1253.500000
# 50%       1743.000000
# 75%       2320.500000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# /tmp/ipykernel_1295/1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3771.000000
# mean        3.328825
# std         1.859969
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 3784         house                  independent   sector 54   5.00
# 224          house                  independent   sector 43   4.50
# 1612         house                  independent  sector 17a   3.87
# 3246         house                  independent  sector 17a   3.93
# 1288         house                  independent   sector 54   5.50
# 503          house                private house   sector 55   7.05
# 862          house                  independent   sector 43  13.50
# 118          house                  independent   sector 11   4.50
# 301          house                  independent   sector 26  14.75
# 667          house                  independent   sector 55   9.19
# 2266         house               dlf city plots   sector 26  20.00
# 1784         house                  independent   sector 26  26.00
# 2891         house                  independent   sector 56  12.39
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
sns.distplot(df['bedRoom'])
# Out:
# /tmp/ipykernel_1295/1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3721.000000
# mean        3.187584
# std         1.382792
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# /tmp/ipykernel_1295/2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 1264         house  adani brahma samsara  sector 60  18.02         28200.0
# 520          house           independent  sector 39   7.00         10000.0
# 1297         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 1264  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 520   7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 1297  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 1264        12      3+       3.0  North-East  Relatively New
# 520         11      3+       4.0  South-East  Relatively New
# 1297        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %% [markdown]
# luxury_score

# %%
sns.distplot(df['luxury_score'])
# Out:
# /tmp/ipykernel_1295/3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(x=df['luxury_score'])
# Out:
# <Axes: xlabel='luxury_score'>

# %%
df.shape
# Out:
# (3721, 23)

# %%
df.to_csv('gurgaon_properties_outlier_treated_1_0.csv')
