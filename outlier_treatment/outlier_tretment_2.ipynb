# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/gurgaon_properties_outlier_treated_1_0.csv')

# %%
pd.set_option('display.max_columns',None)

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.head()
# Out:
#   property_type                           society      sector  price  \
# 0         house  bestech park view aindependentda   sector 81   4.35
# 1          flat           signature global solera  sector 107   0.28
# 2          flat                 hcbs sports ville  sohna road   0.29
# 3          flat                     orchid petals   sector 49   2.55
# 4         house             signature global city  sector 37d   1.27
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7937.0  5481.0                       Plot area 5480(509.11 sq.m.)
# 1          5674.0   493.0                     Carpet area: 489 (45.43 sq.m.)
# 2          5587.0   519.0                     Carpet area: 519 (48.22 sq.m.)
# 3         12318.0  2070.0  Super Built up area 2070(192.31 sq.m.)Built Up...
# 4          8089.0  1570.0                       Plot area 1570(145.86 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum facing       agePossession  \
# ...

# %% [markdown]
# super_builtup_area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# /tmp/ipykernel_2830/4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'],color='teal')
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1915.000000
# mean      1921.658251
# std        767.160169
# min         89.000000
# 25%       1457.000000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1633          flat  bestech park view grand spa    sector 81    4.7
# 3312          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 1633          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3312          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1633        4         4      3+      19.0       North  Relatively New
# 3312        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1633               6926.0            NaN          NaN           0
# 3312              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# built_up_area

# %%
sns.distplot(df['built_up_area'])
# Out:
# /tmp/ipykernel_2830/3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'],color='teal')
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 1655         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1655  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 1655  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 1655          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 1655                1            42

# %% [markdown]
# carpet_area

# %%
sns.distplot(df['carpet_area'])
# Out:
# /tmp/ipykernel_2830/3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 898           flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
# 2519          flat      godrej air  sector 85    2.5          1379.0   1812.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 898   Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 2519  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 898        North      Moderately Old                  NaN            NaN
# 2519  North-East  Under Construction                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 898       11000.0           0             1           0           0       0
# 2519      18122.0           1             0           0           1       1
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[2519,'carpet_area'] = 1812

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# /tmp/ipykernel_2830/2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 45000]
# Out:
#      property_type                       society      sector  price  \
# 671          house        emaar the palm springs   sector 54   24.0
# 673          house                unitech escape   sector 50   10.8
# 705          house            cloudnine cottages  sohna road    5.5
# 798          house        emaar the palm springs   sector 54   14.0
# 2052         house                dlf city plots   sector 26   26.0
# 2511         house            emaar mgf marbella   sector 66   18.0
# 2704         house  project housing board colony   sector 31    8.0
# 2768         house  sushant lok 1 builder floors   sector 43   13.0
# 2770          flat                unitech vistas   sector 70    9.0
# 3384         house                   independent  sector 105    9.9
# 3410         house                   independent   sector 25   13.0
#
#       price_per_sqft    area  \
# 671          66667.0  3600.0
# 673          60000.0  1800.0
# 705          55000.0  1000.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# np.float64(257.0)

# %%
df[(df['area']/df['bedRoom'])<257]
# Out:
#      property_type                  society      sector  price  \
# 1             flat  signature global solera  sector 107   0.28
# 10            flat  signature global solera  sector 107   0.50
# 15           house           sector 57 huda   sector 57   3.80
# 24            flat            gls avenue 51   sector 92   0.39
# 40           house              independent  sector 105   1.20
# ...            ...                      ...         ...    ...
# 3554         house              independent   sector 17   0.32
# 3571         house              independent   sector 13   1.50
# 3612         house              independent   sector 11   2.10
# 3641          flat  signature global solera  sector 107   0.27
# 3708         house           not applicable    sector 4   0.51
#
#       price_per_sqft    area  \
# 1             5680.0   493.0
# 10            7752.0   645.0
# 15           26063.0  1458.0
# 24            6075.0   642.0
# 40           10118.0  1186.0
# ...

# %%
sns.lmplot(x='area',y='bedRoom',data=df, scatter_kws={'color': 'lightgreen'}, line_kws={'color': 'black'})

# %%
df['area-room_ratio']=df['area']/df['bedRoom']

# %%
(df[df['area-room_ratio']<257])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     56
# 3     41
# 5     28
# 6     18
# 4     17
# 9     15
# 8     12
# 7      8
# 10     8
# 1      1
# Name: count, dtype: int64

# %%
df=df[df['area-room_ratio']>100]

# %%
outliers_df=df[(df['area-room_ratio']<257) & (df['bedRoom']>3)]

# %%
outliers_df
# Out:
#      property_type                     society             sector  price  \
# 15           house              sector 57 huda          sector 57   3.80
# 40           house                 independent         sector 105   1.20
# 49           house                 independent           sector 2   3.65
# 73           house   huda housing board colony          sector 31   4.60
# 119          house                 independent          sector 12   1.35
# ...            ...                         ...                ...    ...
# 3538         house                 independent          sector 47   4.60
# 3552         house  rattan vihar rajendra park  dwarka expressway   0.85
# 3553         house                 independent   sector 3 phase 2   0.85
# 3571         house                 independent          sector 13   1.50
# 3612         house                 independent          sector 11   2.10
#
#       price_per_sqft    area  \
# 15           26063.0  1458.0
# ...

# %%
outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# /tmp/ipykernel_2830/3359844150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area-room_ratio']=df['area']/df['bedRoom']
# Out:
# /tmp/ipykernel_2830/2580423485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area-room_ratio']=df['area']/df['bedRoom']

# %%
df[(df['area-room_ratio']<257) & (df['bedRoom']>4)]
# Out:
#      property_type               society            sector  price  \
# 524          house           independent         sector 17   0.32
# 931          house           independent           manesar   0.80
# 1086         house           independent  sector 3 phase 2   1.10
# 1443         house           independent         sector 11   3.50
# 1631         house           independent         sector 12   2.50
# 2141         house           independent           manesar   1.10
# 2678         house              shivpuri          sector 7   2.80
# 2683         house           independent        sector 105   1.10
# 2812         house  bhim nagar, sector 6          sector 6   0.85
# 2884         house           independent          sector 7   1.16
# 2968         house           independent          sector 2   0.98
# 3527         house           independent         sector 12   0.65
# 3553         house           independent  sector 3 phase 2   0.85
#
#       price_per_sqft    area  \
# ...

# %%
df[(df['area-room_ratio']<257) & (df['bedRoom']>4)].shape
# Out:
# (13, 24)

# %%
df=df[~((df['area-room_ratio']<257) & (df['bedRoom']>4))]

# %%
sns.lmplot(x='area',y='bedRoom',data=df, scatter_kws={'color': 'green'}, line_kws={'color': 'black'})

# %%
df.to_csv('gurgaon_properties_outlier_treated_1_1.csv',index=False)
