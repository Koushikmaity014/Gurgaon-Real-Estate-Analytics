# %%
import numpy as np
import pandas as pd

# %%
house=pd.read_csv('/content/house_cleaned.csv')
flat=pd.read_csv('/content/flats_cleaned.csv')

# %%
df = pd.concat([flat,house],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0  4 Bedroom House for sale in Sector 81 Gurgaon         house
# 1               2 BHK Flat in Sector 107 Gurgaon          flat
# 2  5 Bedroom House for sale in Sector 66 Gurgaon         house
# 3                            2 BHK Flat in Sohna          flat
# 4                3 BHK Flat in Sector 49 Gurgaon          flat
#
#                             society  price  price_per_sqft    area  \
# 0  bestech park view aindependentda   4.35          7937.0  5481.0
# 1           signature global solera   0.28          5674.0   493.0
# 2                emaar mgf marbella    NaN             NaN     NaN
# 3                 hcbs sports ville   0.29          5587.0   519.0
# 4                     orchid petals   2.55         12318.0  2070.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                       Plot area 5480(509.11 sq.m.)        4         4
# 1                     Carpet area: 489 (45.43 sq.m.)        2         2
# 2                        Plot area 350(292.64 sq.m.)        5         5
# 3                     Carpet area: 519 (48.22 sq.m.)        2         2
# 4  Super Built up area 2070(192.31 sq.m.)Built Up...        3         4
#
#   balcony           additionalRoom  \
# 0       3  store room,servant room
# 1       2            not available
# 2       3            not available
# 3       1            not available
# 4       3               study room
#
#                                              address  floorNum facing  \
# 0     Sector 81, Sector 81 Gurgaon, Gurgaon, Haryana       2.0  North
# 1               Sector 107 Gurgaon, Gurgaon, Haryana       6.0   West
# 2                Sector 66 Gurgaon, Gurgaon, Haryana       2.0    NaN
# 3                            Sohna, Gurgaon, Haryana       4.0    NaN
# 4  Opposite Sapphire Mall Sohna Road Gurgaon, Sec...       8.0   East
#
#      agePossession                                    nearbyLocations  \
# 0  1 to 5 Year Old  ['Metro Station Kankrola sec 87', 'Sapphire 83...
# 1  1 to 5 Year Old  ['Gurgaon Dreamz Mall', 'Dwarka Expressway', "...
# 2  1 to 5 Year Old  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 3  1 to 5 Year Old  ['The roadside cafe', 'GD Goenka Mess', 'ROyal...
# 4  1 to 5 Year Old  ['Sapphire Mall', 'Omaxe City Centre', 'BigBaz...
#
#                                          description  \
# 0     Near by all amenities like school and hospital
# 1  This lovely 2 bhk apartment/flat in sector 107...
# 2  This property situated in marbella sector 65 g...
# 3  Affordable housing in gurgaon and surrounded b...
# 4  Park pool facing sunny flat full cheque ,this ...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1                                                NaN
# 2  ['5 Fan', '1 Exhaust Fan', '6 Geyser', '1 Micr...
# 3                                                NaN
# 4  ['8 Fan', '1 Exhaust Fan', '3 Geyser', '8 Ligh...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 1  ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 2  ['Private Garden / Terrace', 'Maintenance Staf...
# 3  ['Security / Fire Alarm', 'Intercom Facility',...
# 4  ['Feng Shui / Vaastu Compliant', 'Security / F...
#
#                                               rating
# 0  ['Environment4.5 out of 5', 'Safety4.5 out of ...
# 1  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 2  ['Environment3 out of 5', 'Safety4 out of 5', ...
# 3  ['Green Area4 out of 5', 'Amenities4 out of 5'...
# 4  ['Green Area5 out of 5', 'Construction5 out of...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
